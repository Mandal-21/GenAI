# %% [markdown]
# ### How to recursively split text by characters
#
# This text splitter is the recommended one for generic text. It is parameterized by a list of characters. It tries to split on them in order until the chunks are small enough. The default list is ["\n\n", "\n", " ", ""]. This has the effect of trying to keep all paragraphs (and then sentences, and then words) together as long as possible, as those would generically seem to be the strongest semantically related pieces of text.
#
# How the text is split: by list of characters.
# How the chunk size is measured: by number of characters.
# Below we show example usage.
#
# To obtain the string content directly, use `.split_text`.

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf")
data = loader.load()
data  # Display the first 1000 characters of the first page
# Out:
# [Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 0, 'page_label': '1'}, page_content='CI/CD &\nDEPLOYMENT\nMONITORING &\nCLOUD\nAGENTIC\nFRAMEWORKS'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 1, 'page_label': '2'}, page_content='This course is designed for AI developers, machine learning engineers, data scientists, and\nsoftware engineers looking to build expertise in agentic AI, multi-agent systems, and AI-powered\nautomation. Whether you are new to AI agents or have experience in NLP and GenAI, this course\nwill equip you with the knowledge and hands-on skills required to develop, deploy, and manage AI\nagents at scale. By the end of the course, you will have a strong foundation in agentic AI\nframeworks, multi-agent collaboration, real-world automation, and end-to-end AI deployment,\nalong with practical experience through real-world projects.\nLearning Objectives\n✅  Master AI Agent Frameworks: Build intelligent agents using LangChain, LangGraph,\nCrewAI, Agno, AutoGen, and LangFlow.\n✅  Develop Multi-Agent Systems: Design and deploy collaborative AI agents for real-\nworld tasks.\n✅  Implement RAG & Adaptive RAG: Build retrieval-augmented generation (RAG)\nsystems with vector databases.\n✅  Automate Workflows: Use n8n & LangFlow for AI-powered workflow automation.\n✅  Deploy AI Agents at Scale: Deploy agents using GitHub Actions, Docker, AWS, and\nBentoML.\n✅  Monitor & Optimize AI Agents: Track performance with LangSmith, Opik, and ClearML.\n✅  Build Real-World AI Applications: Create chatbots, financial agents, content\nautomation, and multi-agent systems.\nAgentic And GenAI 2.0                                              Page  2'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 2, 'page_label': '3'}, page_content='Course Information\nA foundational understanding of Python, NLP applications, and Generative AI applications is\nrecommended for this course. You should be comfortable working with Python and have\nexperience building NLP and GenAI applications. While the course will guide you through\nadvanced concepts, prior exposure to these topics will help you grasp the material more\neffectively and accelerate your learning.\nEstimated Time\n4 months 6hrs/week*\nRequired Skill Level\nIntermediate\nThe course is designed to be completed over a duration of approximately 4 months, covering a\nstructured progression from fundamental concepts to advanced agentic AI applications. The\ncurriculum includes theoretical foundations, hands-on coding exercises, real-world projects, and\ndeployment strategies, ensuring a comprehensive learning experience.\nPrerequisites\nAgentic And GenAI 2.0                                              Page  3'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 3, 'page_label': '4'}, page_content='Tools\nAgentic And GenAI 2.0                                              Page  4'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 4, 'page_label': '5'}, page_content='Course Instructors\nKrish NaikChief AI Engineer\nLinkedin\nSourangshu PalSenior Data Scientist\nLinkedin\nMayank AggrawalSenior ML Engineer\nLinkedin\nAgentic And GenAI 2.0                                              Page  5'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 5, 'page_label': '6'}, page_content="In this module, you'll explore the fundamentals of AI agents, understanding what they are and how\nthey function. You'll dive into the differences between Agentic AI, AI Agents, and Generative AI.\nThe module will also introduce you to multi-agent systems and various frameworks used to build\nthem. By the end, you will have a strong grasp of agent-based AI concepts, preparing you to work\nwith agentic AI frameworks in real-world applications.\nIntroduction to Agents\nModule 1\nTopics\nUnderstanding Agents What are Agents?\nAgentic AI Concepts Agentic AI vs AI Agents, Agentic AI vs\nGenerative AI\nMulti-Agent Systems & Frameworks What are Multi-Agents?, Agentic AI\nFrameworks\nAgentic And GenAI 2.0                                              Page  6"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 6, 'page_label': '7'}, page_content="In this module, you'll learn how to use Pydantic for efficient data validation and parsing in Python.\nYou'll start with installation and understanding models and fields. Then, you'll explore core\nvalidation techniques, including working with JSON, data types, and validators. Finally, you'll dive\ninto advanced concepts like validation decorators and monitoring Pydantic with Logfire. By the\nend, you'll be equipped to integrate Pydantic seamlessly into your projects for robust data\nvalidation.\nPydantic - Data Validation\nModule 2\nTopics\nGetting Started with Pydantic Installing, Models, Fields\nCore Validation & Data Handling JSON, Types, Validators, Dataclasses\nAdvanced Validation & Monitoring Validation Decorator, Monitor Pydantic\nwith Logfire\nAgentic And GenAI 2.0                                              Page  7"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 7, 'page_label': '8'}, page_content="In this module, you'll dive into Langchain, an essential framework for building AI-powered\napplications. You'll begin with an introduction to its core components and modules. Next, you'll\nexplore data ingestion and text-splitting techniques to preprocess documents effectively. Finally,\nyou'll learn about embeddings from OpenAI, Ollama, and Hugging Face, and how to store and\nretrieve vectorized data using FAISS and ChromaDB. By the end, you'll have a strong foundation\nfor working with Langchain in real-world AI applications.\nLangchain\nModule 3\nTopics\nIntroduction to Langchain Introduction to Basic Components and\nModules in Langchain\nData Ingestion & Processing Data Ingestion with Document Loaders,\nText Splitting Techniques (Recursive\nCharacter, Character, HTML Header,\nRecursive JSON)\nEmbeddings & Vector Stores Introduction to OpenAI Embedding,\nOllama Embeddings, Hugging Face\nEmbeddings, VectorStores-FAISS,\nVectorStore and Retriever - ChromaDB\nAgentic And GenAI 2.0                                              Page  8"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 8, 'page_label': '9'}, page_content="In this module, you'll explore Langchain Expression Language (LCEL) for building AI-powered\nworkflows. You'll start by working with open-source models using the Groq API. Next, you'll learn\nhow to construct LLMs, prompts, and structured output chains using LCEL. Finally, you'll deploy\nLCEL components as APIs using Langserve, making them accessible for real-world applications.\nBy the end, you'll have the skills to create and deploy LCEL-based AI solutions efficiently.\nLCEL (Langchain Expression Language)\nModule 4\nTopics\nGetting Started with LCEL Getting Started with Open Source\nModels Using Groq API\nBuilding LCEL Chains Building LLM, Prompt, and Stroutput\nChains with LCEL\nDeployment & API Integration Deploy Langserve Runnable and Chain\nas API\nAgentic And GenAI 2.0                                              Page  9"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 9, 'page_label': '10'}, page_content="In this module, you'll explore LangGraph, a framework for building AI-powered workflows using\ngraph-based structures. You'll begin with an introduction to its core concepts, including simple\ngraphs and LangGraph Studio. Next, you'll dive into key components like chains, routers, and\nagents with memory. Finally, you'll learn how to deploy LangGraph-based applications. By the end,\nyou'll have a solid understanding of LangGraph and its practical applications in AI development.\nLangGraph Introduction\nModule 5\nTopics\nGetting Started with LangGraph Introduction, Simple Graph, LangGraph\nStudio\nCore Components & Agents Chain, Router, Agent, Agent with\nMemory\nDeployment Essentials Intro to Deployment\nAgentic And GenAI 2.0                                              Page  10"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 10, 'page_label': '11'}, page_content="In this module, you'll dive into managing state and memory in LangGraph. You'll start by\nunderstanding state schemas and how multiple schemas can be utilized. Then, you'll explore\nmemory optimization techniques, including state reducers and message filtering, to efficiently\nhandle data in AI workflows. By the end, you'll have a solid grasp of state and memory\nmanagement, enabling you to build scalable and efficient LangGraph applications.\nState & Memory in LangGraph\nModule 6\nTopics\nUnderstanding State Management Introduction, State Schema, Multiple\nSchemas\nMemory Optimization State Reducers, Trim and Filter\nMessages\nAgentic And GenAI 2.0                                            Page  11"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 11, 'page_label': '12'}, page_content="In this module, you'll explore techniques to enhance user experience and integrate human\nfeedback in LangGraph workflows. You'll start with real-time streaming and breakpoints to control\nexecution flow. Then, you'll dive into editing states dynamically and incorporating human\nfeedback. Finally, you'll learn advanced debugging techniques like time travel for reviewing past\nstates. By the end, you'll be able to build interactive, user-friendly AI applications with LangGraph.\nUX and Human in Loop with LangGraph\nModule 7\nTopics\nEnhancing User Experience Streaming, Breakpoints\nHuman Feedback & State Control Editing State and Human Feedback,\nDynamic Breakpoints\nAdvanced Debugging Time Travel\nAgentic And GenAI 2.0                                            Page  12"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 12, 'page_label': '13'}, page_content="In this module, you'll learn how to deploy LangGraph applications efficiently. You'll start with\nfundamental deployment concepts and the process of creating a deployment. Then, you'll explore\nhow to connect and interact with your deployed LangGraph applications. By the end, you'll have\nthe skills to deploy and manage LangGraph solutions in real-world environments. \nLangGraph Deployments\nModule 8\nTopics\nDeployment Basics Deployment Concepts, Creating a\nDeployment\nIntegration & Access Connecting to a Deployment\nAgentic And GenAI 2.0                                            Page  13"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 13, 'page_label': '14'}, page_content="In this module, you'll explore Agno, a lightweight framework for building AI agents. You'll start by\nunderstanding its core components, including agents, teams, models, and tools. Next, you'll learn\nhow Agno handles data storage using chunking, vector databases, and embeddings. You'll dive\ninto workflows, agent observability, and UI features, enabling you to build and monitor intelligent\nagent systems effectively. You will also understand web search agents that retrieve and process\nonline information. Then, you'll delve into financial agents designed for analyzing market trends\nand financial data. Finally, you'll learn about RAG (Retrieval-Augmented Generation) agents,\nwhich enhance LLM capabilities with external knowledge retrieval.\nAgno - Light Framework\nModule 9\nTopics\nCore Concepts & Components Agents in Agno, Teams, Models, Tools,\nKnowledge\nData Handling & Storage Chunking, VectorDBs, Storage,\nEmbeddings\nWorkflows & Observability Workflows, Agent Observability, Agent\nPlayground, Agent UI\nAgno Projects Web Search Agents, Financial Agents,\nRAG Agents\nAgentic And GenAI 2.0                                            Page  14"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 14, 'page_label': '15'}, page_content="In this module, you'll dive into Agentic RAG (Retrieval-Augmented Generation) techniques, which\nenhance AI models with dynamic retrieval capabilities. You'll begin with adaptive RAG, learning\nhow to implement it locally and with services like Cohere. Then, you'll explore controlled RAG\napproaches like Agentic RAG and C-RAG, including their local implementations. Finally, you'll\ndiscover self-optimizing RAG methods that leverage vector databases for smarter knowledge\nretrieval. By the end, you'll be able to build advanced RAG-powered AI agents.\nAgentic RAG\nModule 10\nTopics\nAdaptive Retrieval-Augmented\nGeneration\nAdaptive RAG, Adaptive RAG with\nCohere, Adaptive RAG in Local\nControlled & Contextual RAG Agentic RAG, C-RAG, C-RAG in Local\nSelf-Optimizing RAG Self RAG, Self RAG in Local, Self RAG\nwith VectorDB\nAgentic And GenAI 2.0                                            Page  15"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 15, 'page_label': '16'}, page_content="In this module, you'll explore LangSmith, a powerful tool for managing AI workflows. You'll start\nwith an overview of its key features and role in AI development. Next, you'll learn how to set up\nLangSmith and navigate its user interface to utilize core functionalities. Finally, you'll dive into data\nintegration, preprocessing, and workflow pipelines, ensuring a seamless AI development process.\nBy the end, you'll have a strong foundation in using LangSmith to streamline AI projects.\nLangSmith\nModule 11\nTopics\nIntroduction & Setup What is LangSmith? Overview and Key\nFeatures, LangSmith in the AI\nDevelopment Workflow, Setting Up\nLangSmith: Installation and\nConfiguration\nCore Functionalities & UI Exploring the User Interface and Core\nFunctionalities, Understanding Workflow\nPipelines in LangSmith\nData Handling & Integration Data Integration in LangSmith,\nPreprocessing and Cleaning Data\nAgentic And GenAI 2.0                                            Page  16"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 16, 'page_label': '17'}, page_content="In this module, you'll learn how to design and implement multi-agent systems using LangGraph.\nYou'll start by building agent nodes and defining their roles. Next, you'll explore communication\nprotocols and coordination mechanisms that enable agents to work together effectively. Finally,\nyou'll learn how to scale multi-agent systems and apply your knowledge to real-world use cases.\nBy the end, you'll be able to create intelligent and scalable multi-agent architectures.\nDesigning Multi-Agent Systems with\nLangGraph\nModule 12\nTopics\nBuilding Agent Nodes & Roles Building Agent Nodes in LangGraph,\nDefining Tasks and Roles for Agents\nAgent Communication & Coordination Agent Communication Protocols and\nCoordination\nScalability & Real-World Applications Creating Scalable Multi-Agent Systems\nin LangGraph, Building a Real-World\nMulti-Agent System\nAgentic And GenAI 2.0                                            Page  17"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 17, 'page_label': '18'}, page_content="In this module, you'll explore CrewAI, a powerful multi-agent platform for building AI-driven\nworkflows. You'll begin with an introduction to its key features and capabilities. Next, you'll learn\nabout agent collaboration, communication, and workflow automation. You'll also discover how to\ncustomize CrewAI by managing data, implementing memory, defining roles, and using advanced\ntools. Finally, you'll integrate LangChain tools and monitor your CrewAI applications with Opik. By\nthe end, you'll be ready to design and deploy scalable multi-agent systems.\nCrewAI - Multi-Agent Platform\nModule 13\nTopics\nIntroduction & Core Features Definition and Overview, Key Features\nand Capabilities\nAgent Collaboration & Communication Crew Collaboration Framework, AI-\nAgent Communication, Workflow\nAutomation in CrewAI\nCustomization & Advanced\nCapabilities\nCustomizing CrewAI, Managing Data\nAcross Agents, Role-playing, Memory,\nTools, Focus, Guardrails\nIntegration & Monitoring Using LangChain Tools, Monitor your\nCrewAI applications with Opik\nAgentic And GenAI 2.0                                            Page  18"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 18, 'page_label': '19'}, page_content="In this module, you'll explore LangFlow, a low-code tool for building LLM applications with ease.\nYou'll begin with an introduction to its key features and use cases. Then, you'll learn how to set up\nyour LangFlow environment and navigate its UI. Finally, you'll dive into core concepts such as\nnodes, chains, and prompts before building your first LangFlow application. By the end, you'll be\nable to create and deploy LLM-powered workflows effortlessly\nLangFlow - Low Code Tool\nModule 14\nTopics\nIntroduction & Use Cases What is LangFlow? Overview and Use\nCases, Key Features of LangFlow for\nLLM Applications\nSetup & UI Navigation Setting Up Your LangFlow Environment,\nUnderstanding LangFlow UI and\nWorkflows\nCore Concepts & Quick Start Key Terminologies in LangFlow (Nodes,\nChains, Prompts), Quick Start: Creating\nYour First LangFlow Application\nAgentic And GenAI 2.0                                            Page  19"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 19, 'page_label': '20'}, page_content="In this module, you'll dive into the foundational elements of LangFlow. You'll begin by\nunderstanding core concepts like nodes, chains, and how LLMs integrate with LangFlow. Next,\nyou'll explore workflow customization, comparing pre-built and custom workflows while learning\nabout commonly used nodes. Finally, you'll cover prompt engineering and how to seamlessly\nintegrate LangChain with LangFlow. By the end, you'll have the knowledge to build and optimize\nintelligent workflows efficiently.\nBuilding Blocks of LangFlow\nModule 15\nTopics\nCore Concepts & Integration Nodes and Chains: Core Concepts,\nUnderstanding LLMs and Their\nIntegration with LangFlow\nWorkflows & Customization Pre-built vs. Custom Workflows,\nExploring Commonly Used LangFlow\nNodes\nPrompt Engineering & LangChain\nIntegration\nPrompt Engineering Basics in LangFlow,\nLangChain Integration: Using LangFlow\nwith LangChain\nAgentic And GenAI 2.0                                            Page  20"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 20, 'page_label': '21'}, page_content="In this module, you'll learn how to integrate LangFlow with various third-party tools and services.\nYou'll start by connecting LangFlow with different data sources like SQL, CSV, and NoSQL\ndatabases, along with external REST APIs. Next, you'll explore model integrations, including\nOpenAI, Hugging Face, and vector databases for embeddings. Finally, you'll delve into workflow\nautomation and chatbot development using LangFlow. By the end, you'll be able to build\nintelligent, automated applications with seamless integrations.\nIntegrating LangFlow with Third-Party\nTools\nModule 16\nTopics\nData & API Integration Connecting LangFlow with Data\nSources (SQL, CSV, NoSQL), API\nIntegration for External Services (REST\nAPIs)\nModel & Vector Database Integration Using LangFlow with Vector Databases\nfor Embeddings, LangFlow with OpenAI\nand Hugging Face Models\nWorkflow Automation & Chatbots Automating Workflows Using LangFlow,\nBuilding Chatbot Applications with\nLangFlow\nAgentic And GenAI 2.0                                            Page  21"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 21, 'page_label': '22'}, page_content="In this module, you'll get a comprehensive understanding of n8n, a powerful workflow automation\nplatform. You'll begin with the fundamentals, covering workflows, nodes, and core concepts. Then,\nyou'll explore APIs, webhooks, and error-handling techniques to ensure robust automation. You'll\nwill also learn to build AI-powered chatbots using Retrieval-Augmented Generation (RAG). Next,\nyou'll explore automation for content creation, such as generating blog posts with WordPress and\nalso implement AI-driven transcription and summarization workflows using Notion. Finally, you'll\ndive into AI-driven automation, including building AI agent chatbots and integrating tools like\nWhatsApp, Telegram, and calendars. By the end, you'll have the skills to create scalable and\nintelligent workflow automations with n8n.\nn8n\nModule 17\nTopics\nFundamentals & Core Concepts Introduction and Workflows, Interface,\nNodes, Core Workflow Concepts, Data in\nn8n\nAPI, Webhooks & Error Handling APIs and Webhooks, Useful Nodes, Error\nHandling, Debugging\nAI & Automation in n8n Build AI Agent Chatbot, Automations\nwith LLMs, Tools Integrations\n(WhatsApp, Telegram, Calendar)\nn8n Projects Building Automated RAG Chatbots,\nAutomate Blog Generation with\nWordPress, Automated Transcribe and\nSummarize with Notion\nAgentic And GenAI 2.0                                            Page  22"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 22, 'page_label': '23'}, page_content="In this module, you’ll get an introduction to AutoGen, an open-source framework for building and\nmanaging AI agents. You'll start with installation and core concepts, exploring how agents interact\nwithin goals, environments, and actions. You’ll then move on to designing agentic systems,\nincorporating feedback loops and decision-making frameworks. Finally, you'll explore multi-agent\ncollaboration and deployment strategies, ensuring scalability and performance monitoring. By the\nend of this module, you'll have a solid foundation in AutoGen and its applications in AI-driven\nautomation.\nAutogen\nModule 18\nTopics\nGetting Started with Autogen Overview of Autogen Framework,\nInstallation and Environment Setup\nCore Concepts of Autogen Agents, Goals, Environments, and\nActions, APIs, Libraries, and Tools\nBuilding Agentic Systems Designing and Developing Agentic\nSystems, Framework for Agentic\nDecision-Making\nAgent Interactions & Learning Communication Between Agents,\nImplementing Feedback Loops, Agent\nLearning and Adaptation\nMulti-Agent Collaboration Multi-Agent Collaboration, Deployment,\nMonitoring Agent Performance\nAgentic And GenAI 2.0                                            Page  23"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 23, 'page_label': '24'}, page_content="This module covers the full deployment pipeline for AI agents, providing hands-on experience with\nessential DevOps tools such as GitHub Actions, Docker, and cloud platforms like AWS S3, ECR,\nEC2, and Bedrock. You'll also explore model serving with BentoML. After mastering these\ndeployment concepts, you'll work on multiple end-to-end Agentic AI projects, applying these skills\nto real-world scenarios. By the end of this module, you'll be equipped to deploy, manage, and\nscale AI agents efficiently.\nDeploying AI Agents Stack & End-to-End\nAgentic AI Projects\nModule 19\nTopics\nCI/CD for AI Agents GitHub Actions, Docker\nCloud Infrastructure AWS S3, AWS ECR, AWS EC2, AWS\nBedrock\nModel Serving & Deployment BentoML\nEnd-to-End Agentic AI Projects Multiple Agentic AI Project\nAgentic And GenAI 2.0                                            Page  24")]

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
final_documents = text_splitter.split_documents(data)
final_documents
# Out:
# [Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 0, 'page_label': '1'}, page_content='CI/CD &\nDEPLOYMENT\nMONITORING &\nCLOUD\nAGENTIC\nFRAMEWORKS'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 1, 'page_label': '2'}, page_content='This course is designed for AI developers, machine learning engineers, data scientists, and\nsoftware engineers looking to build expertise in agentic AI, multi-agent systems, and AI-powered\nautomation. Whether you are new to AI agents or have experience in NLP and GenAI, this course\nwill equip you with the knowledge and hands-on skills required to develop, deploy, and manage AI\nagents at scale. By the end of the course, you will have a strong foundation in agentic AI'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 1, 'page_label': '2'}, page_content='frameworks, multi-agent collaboration, real-world automation, and end-to-end AI deployment,\nalong with practical experience through real-world projects.\nLearning Objectives\n✅  Master AI Agent Frameworks: Build intelligent agents using LangChain, LangGraph,\nCrewAI, Agno, AutoGen, and LangFlow.\n✅  Develop Multi-Agent Systems: Design and deploy collaborative AI agents for real-\nworld tasks.\n✅  Implement RAG & Adaptive RAG: Build retrieval-augmented generation (RAG)\nsystems with vector databases.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 1, 'page_label': '2'}, page_content='systems with vector databases.\n✅  Automate Workflows: Use n8n & LangFlow for AI-powered workflow automation.\n✅  Deploy AI Agents at Scale: Deploy agents using GitHub Actions, Docker, AWS, and\nBentoML.\n✅  Monitor & Optimize AI Agents: Track performance with LangSmith, Opik, and ClearML.\n✅  Build Real-World AI Applications: Create chatbots, financial agents, content\nautomation, and multi-agent systems.\nAgentic And GenAI 2.0                                              Page  2'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 2, 'page_label': '3'}, page_content='Course Information\nA foundational understanding of Python, NLP applications, and Generative AI applications is\nrecommended for this course. You should be comfortable working with Python and have\nexperience building NLP and GenAI applications. While the course will guide you through\nadvanced concepts, prior exposure to these topics will help you grasp the material more\neffectively and accelerate your learning.\nEstimated Time\n4 months 6hrs/week*\nRequired Skill Level\nIntermediate'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 2, 'page_label': '3'}, page_content='Required Skill Level\nIntermediate\nThe course is designed to be completed over a duration of approximately 4 months, covering a\nstructured progression from fundamental concepts to advanced agentic AI applications. The\ncurriculum includes theoretical foundations, hands-on coding exercises, real-world projects, and\ndeployment strategies, ensuring a comprehensive learning experience.\nPrerequisites\nAgentic And GenAI 2.0                                              Page  3'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 3, 'page_label': '4'}, page_content='Tools\nAgentic And GenAI 2.0                                              Page  4'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 4, 'page_label': '5'}, page_content='Course Instructors\nKrish NaikChief AI Engineer\nLinkedin\nSourangshu PalSenior Data Scientist\nLinkedin\nMayank AggrawalSenior ML Engineer\nLinkedin\nAgentic And GenAI 2.0                                              Page  5'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 5, 'page_label': '6'}, page_content="In this module, you'll explore the fundamentals of AI agents, understanding what they are and how\nthey function. You'll dive into the differences between Agentic AI, AI Agents, and Generative AI.\nThe module will also introduce you to multi-agent systems and various frameworks used to build\nthem. By the end, you will have a strong grasp of agent-based AI concepts, preparing you to work\nwith agentic AI frameworks in real-world applications.\nIntroduction to Agents\nModule 1\nTopics"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 5, 'page_label': '6'}, page_content='Introduction to Agents\nModule 1\nTopics\nUnderstanding Agents What are Agents?\nAgentic AI Concepts Agentic AI vs AI Agents, Agentic AI vs\nGenerative AI\nMulti-Agent Systems & Frameworks What are Multi-Agents?, Agentic AI\nFrameworks\nAgentic And GenAI 2.0                                              Page  6'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 6, 'page_label': '7'}, page_content="In this module, you'll learn how to use Pydantic for efficient data validation and parsing in Python.\nYou'll start with installation and understanding models and fields. Then, you'll explore core\nvalidation techniques, including working with JSON, data types, and validators. Finally, you'll dive\ninto advanced concepts like validation decorators and monitoring Pydantic with Logfire. By the\nend, you'll be equipped to integrate Pydantic seamlessly into your projects for robust data\nvalidation."),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 6, 'page_label': '7'}, page_content='validation.\nPydantic - Data Validation\nModule 2\nTopics\nGetting Started with Pydantic Installing, Models, Fields\nCore Validation & Data Handling JSON, Types, Validators, Dataclasses\nAdvanced Validation & Monitoring Validation Decorator, Monitor Pydantic\nwith Logfire\nAgentic And GenAI 2.0                                              Page  7'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 7, 'page_label': '8'}, page_content="In this module, you'll dive into Langchain, an essential framework for building AI-powered\napplications. You'll begin with an introduction to its core components and modules. Next, you'll\nexplore data ingestion and text-splitting techniques to preprocess documents effectively. Finally,\nyou'll learn about embeddings from OpenAI, Ollama, and Hugging Face, and how to store and\nretrieve vectorized data using FAISS and ChromaDB. By the end, you'll have a strong foundation"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 7, 'page_label': '8'}, page_content='for working with Langchain in real-world AI applications.\nLangchain\nModule 3\nTopics\nIntroduction to Langchain Introduction to Basic Components and\nModules in Langchain\nData Ingestion & Processing Data Ingestion with Document Loaders,\nText Splitting Techniques (Recursive\nCharacter, Character, HTML Header,\nRecursive JSON)\nEmbeddings & Vector Stores Introduction to OpenAI Embedding,\nOllama Embeddings, Hugging Face\nEmbeddings, VectorStores-FAISS,\nVectorStore and Retriever - ChromaDB'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 7, 'page_label': '8'}, page_content='VectorStore and Retriever - ChromaDB\nAgentic And GenAI 2.0                                              Page  8'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 8, 'page_label': '9'}, page_content="In this module, you'll explore Langchain Expression Language (LCEL) for building AI-powered\nworkflows. You'll start by working with open-source models using the Groq API. Next, you'll learn\nhow to construct LLMs, prompts, and structured output chains using LCEL. Finally, you'll deploy\nLCEL components as APIs using Langserve, making them accessible for real-world applications.\nBy the end, you'll have the skills to create and deploy LCEL-based AI solutions efficiently."),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 8, 'page_label': '9'}, page_content='LCEL (Langchain Expression Language)\nModule 4\nTopics\nGetting Started with LCEL Getting Started with Open Source\nModels Using Groq API\nBuilding LCEL Chains Building LLM, Prompt, and Stroutput\nChains with LCEL\nDeployment & API Integration Deploy Langserve Runnable and Chain\nas API\nAgentic And GenAI 2.0                                              Page  9'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 9, 'page_label': '10'}, page_content="In this module, you'll explore LangGraph, a framework for building AI-powered workflows using\ngraph-based structures. You'll begin with an introduction to its core concepts, including simple\ngraphs and LangGraph Studio. Next, you'll dive into key components like chains, routers, and\nagents with memory. Finally, you'll learn how to deploy LangGraph-based applications. By the end,\nyou'll have a solid understanding of LangGraph and its practical applications in AI development."),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 9, 'page_label': '10'}, page_content='LangGraph Introduction\nModule 5\nTopics\nGetting Started with LangGraph Introduction, Simple Graph, LangGraph\nStudio\nCore Components & Agents Chain, Router, Agent, Agent with\nMemory\nDeployment Essentials Intro to Deployment\nAgentic And GenAI 2.0                                              Page  10'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 10, 'page_label': '11'}, page_content="In this module, you'll dive into managing state and memory in LangGraph. You'll start by\nunderstanding state schemas and how multiple schemas can be utilized. Then, you'll explore\nmemory optimization techniques, including state reducers and message filtering, to efficiently\nhandle data in AI workflows. By the end, you'll have a solid grasp of state and memory\nmanagement, enabling you to build scalable and efficient LangGraph applications.\nState & Memory in LangGraph\nModule 6\nTopics"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 10, 'page_label': '11'}, page_content='State & Memory in LangGraph\nModule 6\nTopics\nUnderstanding State Management Introduction, State Schema, Multiple\nSchemas\nMemory Optimization State Reducers, Trim and Filter\nMessages\nAgentic And GenAI 2.0                                            Page  11'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 11, 'page_label': '12'}, page_content="In this module, you'll explore techniques to enhance user experience and integrate human\nfeedback in LangGraph workflows. You'll start with real-time streaming and breakpoints to control\nexecution flow. Then, you'll dive into editing states dynamically and incorporating human\nfeedback. Finally, you'll learn advanced debugging techniques like time travel for reviewing past\nstates. By the end, you'll be able to build interactive, user-friendly AI applications with LangGraph."),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 11, 'page_label': '12'}, page_content='UX and Human in Loop with LangGraph\nModule 7\nTopics\nEnhancing User Experience Streaming, Breakpoints\nHuman Feedback & State Control Editing State and Human Feedback,\nDynamic Breakpoints\nAdvanced Debugging Time Travel\nAgentic And GenAI 2.0                                            Page  12'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 12, 'page_label': '13'}, page_content="In this module, you'll learn how to deploy LangGraph applications efficiently. You'll start with\nfundamental deployment concepts and the process of creating a deployment. Then, you'll explore\nhow to connect and interact with your deployed LangGraph applications. By the end, you'll have\nthe skills to deploy and manage LangGraph solutions in real-world environments. \nLangGraph Deployments\nModule 8\nTopics\nDeployment Basics Deployment Concepts, Creating a\nDeployment"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 12, 'page_label': '13'}, page_content='Deployment\nIntegration & Access Connecting to a Deployment\nAgentic And GenAI 2.0                                            Page  13'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 13, 'page_label': '14'}, page_content="In this module, you'll explore Agno, a lightweight framework for building AI agents. You'll start by\nunderstanding its core components, including agents, teams, models, and tools. Next, you'll learn\nhow Agno handles data storage using chunking, vector databases, and embeddings. You'll dive\ninto workflows, agent observability, and UI features, enabling you to build and monitor intelligent\nagent systems effectively. You will also understand web search agents that retrieve and process"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 13, 'page_label': '14'}, page_content="online information. Then, you'll delve into financial agents designed for analyzing market trends\nand financial data. Finally, you'll learn about RAG (Retrieval-Augmented Generation) agents,\nwhich enhance LLM capabilities with external knowledge retrieval.\nAgno - Light Framework\nModule 9\nTopics\nCore Concepts & Components Agents in Agno, Teams, Models, Tools,\nKnowledge\nData Handling & Storage Chunking, VectorDBs, Storage,\nEmbeddings\nWorkflows & Observability Workflows, Agent Observability, Agent"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 13, 'page_label': '14'}, page_content='Playground, Agent UI\nAgno Projects Web Search Agents, Financial Agents,\nRAG Agents\nAgentic And GenAI 2.0                                            Page  14'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 14, 'page_label': '15'}, page_content="In this module, you'll dive into Agentic RAG (Retrieval-Augmented Generation) techniques, which\nenhance AI models with dynamic retrieval capabilities. You'll begin with adaptive RAG, learning\nhow to implement it locally and with services like Cohere. Then, you'll explore controlled RAG\napproaches like Agentic RAG and C-RAG, including their local implementations. Finally, you'll\ndiscover self-optimizing RAG methods that leverage vector databases for smarter knowledge"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 14, 'page_label': '15'}, page_content="retrieval. By the end, you'll be able to build advanced RAG-powered AI agents.\nAgentic RAG\nModule 10\nTopics\nAdaptive Retrieval-Augmented\nGeneration\nAdaptive RAG, Adaptive RAG with\nCohere, Adaptive RAG in Local\nControlled & Contextual RAG Agentic RAG, C-RAG, C-RAG in Local\nSelf-Optimizing RAG Self RAG, Self RAG in Local, Self RAG\nwith VectorDB\nAgentic And GenAI 2.0                                            Page  15"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 15, 'page_label': '16'}, page_content="In this module, you'll explore LangSmith, a powerful tool for managing AI workflows. You'll start\nwith an overview of its key features and role in AI development. Next, you'll learn how to set up\nLangSmith and navigate its user interface to utilize core functionalities. Finally, you'll dive into data\nintegration, preprocessing, and workflow pipelines, ensuring a seamless AI development process.\nBy the end, you'll have a strong foundation in using LangSmith to streamline AI projects.\nLangSmith"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 15, 'page_label': '16'}, page_content='LangSmith\nModule 11\nTopics\nIntroduction & Setup What is LangSmith? Overview and Key\nFeatures, LangSmith in the AI\nDevelopment Workflow, Setting Up\nLangSmith: Installation and\nConfiguration\nCore Functionalities & UI Exploring the User Interface and Core\nFunctionalities, Understanding Workflow\nPipelines in LangSmith\nData Handling & Integration Data Integration in LangSmith,\nPreprocessing and Cleaning Data\nAgentic And GenAI 2.0                                            Page  16'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 16, 'page_label': '17'}, page_content="In this module, you'll learn how to design and implement multi-agent systems using LangGraph.\nYou'll start by building agent nodes and defining their roles. Next, you'll explore communication\nprotocols and coordination mechanisms that enable agents to work together effectively. Finally,\nyou'll learn how to scale multi-agent systems and apply your knowledge to real-world use cases.\nBy the end, you'll be able to create intelligent and scalable multi-agent architectures."),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 16, 'page_label': '17'}, page_content='Designing Multi-Agent Systems with\nLangGraph\nModule 12\nTopics\nBuilding Agent Nodes & Roles Building Agent Nodes in LangGraph,\nDefining Tasks and Roles for Agents\nAgent Communication & Coordination Agent Communication Protocols and\nCoordination\nScalability & Real-World Applications Creating Scalable Multi-Agent Systems\nin LangGraph, Building a Real-World\nMulti-Agent System\nAgentic And GenAI 2.0                                            Page  17'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 17, 'page_label': '18'}, page_content="In this module, you'll explore CrewAI, a powerful multi-agent platform for building AI-driven\nworkflows. You'll begin with an introduction to its key features and capabilities. Next, you'll learn\nabout agent collaboration, communication, and workflow automation. You'll also discover how to\ncustomize CrewAI by managing data, implementing memory, defining roles, and using advanced\ntools. Finally, you'll integrate LangChain tools and monitor your CrewAI applications with Opik. By"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 17, 'page_label': '18'}, page_content="the end, you'll be ready to design and deploy scalable multi-agent systems.\nCrewAI - Multi-Agent Platform\nModule 13\nTopics\nIntroduction & Core Features Definition and Overview, Key Features\nand Capabilities\nAgent Collaboration & Communication Crew Collaboration Framework, AI-\nAgent Communication, Workflow\nAutomation in CrewAI\nCustomization & Advanced\nCapabilities\nCustomizing CrewAI, Managing Data\nAcross Agents, Role-playing, Memory,\nTools, Focus, Guardrails"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 17, 'page_label': '18'}, page_content='Tools, Focus, Guardrails\nIntegration & Monitoring Using LangChain Tools, Monitor your\nCrewAI applications with Opik\nAgentic And GenAI 2.0                                            Page  18'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 18, 'page_label': '19'}, page_content="In this module, you'll explore LangFlow, a low-code tool for building LLM applications with ease.\nYou'll begin with an introduction to its key features and use cases. Then, you'll learn how to set up\nyour LangFlow environment and navigate its UI. Finally, you'll dive into core concepts such as\nnodes, chains, and prompts before building your first LangFlow application. By the end, you'll be\nable to create and deploy LLM-powered workflows effortlessly\nLangFlow - Low Code Tool\nModule 14\nTopics"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 18, 'page_label': '19'}, page_content='LangFlow - Low Code Tool\nModule 14\nTopics\nIntroduction & Use Cases What is LangFlow? Overview and Use\nCases, Key Features of LangFlow for\nLLM Applications\nSetup & UI Navigation Setting Up Your LangFlow Environment,\nUnderstanding LangFlow UI and\nWorkflows\nCore Concepts & Quick Start Key Terminologies in LangFlow (Nodes,\nChains, Prompts), Quick Start: Creating\nYour First LangFlow Application\nAgentic And GenAI 2.0                                            Page  19'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 19, 'page_label': '20'}, page_content="In this module, you'll dive into the foundational elements of LangFlow. You'll begin by\nunderstanding core concepts like nodes, chains, and how LLMs integrate with LangFlow. Next,\nyou'll explore workflow customization, comparing pre-built and custom workflows while learning\nabout commonly used nodes. Finally, you'll cover prompt engineering and how to seamlessly\nintegrate LangChain with LangFlow. By the end, you'll have the knowledge to build and optimize\nintelligent workflows efficiently."),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 19, 'page_label': '20'}, page_content='intelligent workflows efficiently.\nBuilding Blocks of LangFlow\nModule 15\nTopics\nCore Concepts & Integration Nodes and Chains: Core Concepts,\nUnderstanding LLMs and Their\nIntegration with LangFlow\nWorkflows & Customization Pre-built vs. Custom Workflows,\nExploring Commonly Used LangFlow\nNodes\nPrompt Engineering & LangChain\nIntegration\nPrompt Engineering Basics in LangFlow,\nLangChain Integration: Using LangFlow\nwith LangChain'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 19, 'page_label': '20'}, page_content='with LangChain\nAgentic And GenAI 2.0                                            Page  20'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 20, 'page_label': '21'}, page_content="In this module, you'll learn how to integrate LangFlow with various third-party tools and services.\nYou'll start by connecting LangFlow with different data sources like SQL, CSV, and NoSQL\ndatabases, along with external REST APIs. Next, you'll explore model integrations, including\nOpenAI, Hugging Face, and vector databases for embeddings. Finally, you'll delve into workflow\nautomation and chatbot development using LangFlow. By the end, you'll be able to build"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 20, 'page_label': '21'}, page_content='intelligent, automated applications with seamless integrations.\nIntegrating LangFlow with Third-Party\nTools\nModule 16\nTopics\nData & API Integration Connecting LangFlow with Data\nSources (SQL, CSV, NoSQL), API\nIntegration for External Services (REST\nAPIs)\nModel & Vector Database Integration Using LangFlow with Vector Databases\nfor Embeddings, LangFlow with OpenAI\nand Hugging Face Models\nWorkflow Automation & Chatbots Automating Workflows Using LangFlow,\nBuilding Chatbot Applications with'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 20, 'page_label': '21'}, page_content='Building Chatbot Applications with\nLangFlow\nAgentic And GenAI 2.0                                            Page  21'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 21, 'page_label': '22'}, page_content="In this module, you'll get a comprehensive understanding of n8n, a powerful workflow automation\nplatform. You'll begin with the fundamentals, covering workflows, nodes, and core concepts. Then,\nyou'll explore APIs, webhooks, and error-handling techniques to ensure robust automation. You'll\nwill also learn to build AI-powered chatbots using Retrieval-Augmented Generation (RAG). Next,\nyou'll explore automation for content creation, such as generating blog posts with WordPress and"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 21, 'page_label': '22'}, page_content="also implement AI-driven transcription and summarization workflows using Notion. Finally, you'll\ndive into AI-driven automation, including building AI agent chatbots and integrating tools like\nWhatsApp, Telegram, and calendars. By the end, you'll have the skills to create scalable and\nintelligent workflow automations with n8n.\nn8n\nModule 17\nTopics\nFundamentals & Core Concepts Introduction and Workflows, Interface,\nNodes, Core Workflow Concepts, Data in\nn8n"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 21, 'page_label': '22'}, page_content='Nodes, Core Workflow Concepts, Data in\nn8n\nAPI, Webhooks & Error Handling APIs and Webhooks, Useful Nodes, Error\nHandling, Debugging\nAI & Automation in n8n Build AI Agent Chatbot, Automations\nwith LLMs, Tools Integrations\n(WhatsApp, Telegram, Calendar)\nn8n Projects Building Automated RAG Chatbots,\nAutomate Blog Generation with\nWordPress, Automated Transcribe and\nSummarize with Notion\nAgentic And GenAI 2.0                                            Page  22'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 22, 'page_label': '23'}, page_content="In this module, you’ll get an introduction to AutoGen, an open-source framework for building and\nmanaging AI agents. You'll start with installation and core concepts, exploring how agents interact\nwithin goals, environments, and actions. You’ll then move on to designing agentic systems,\nincorporating feedback loops and decision-making frameworks. Finally, you'll explore multi-agent\ncollaboration and deployment strategies, ensuring scalability and performance monitoring. By the"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 22, 'page_label': '23'}, page_content="end of this module, you'll have a solid foundation in AutoGen and its applications in AI-driven\nautomation.\nAutogen\nModule 18\nTopics\nGetting Started with Autogen Overview of Autogen Framework,\nInstallation and Environment Setup\nCore Concepts of Autogen Agents, Goals, Environments, and\nActions, APIs, Libraries, and Tools\nBuilding Agentic Systems Designing and Developing Agentic\nSystems, Framework for Agentic\nDecision-Making\nAgent Interactions & Learning Communication Between Agents,"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 22, 'page_label': '23'}, page_content='Implementing Feedback Loops, Agent\nLearning and Adaptation\nMulti-Agent Collaboration Multi-Agent Collaboration, Deployment,\nMonitoring Agent Performance\nAgentic And GenAI 2.0                                            Page  23'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 23, 'page_label': '24'}, page_content="This module covers the full deployment pipeline for AI agents, providing hands-on experience with\nessential DevOps tools such as GitHub Actions, Docker, and cloud platforms like AWS S3, ECR,\nEC2, and Bedrock. You'll also explore model serving with BentoML. After mastering these\ndeployment concepts, you'll work on multiple end-to-end Agentic AI projects, applying these skills\nto real-world scenarios. By the end of this module, you'll be equipped to deploy, manage, and\nscale AI agents efficiently."),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 23, 'page_label': '24'}, page_content='scale AI agents efficiently.\nDeploying AI Agents Stack & End-to-End\nAgentic AI Projects\nModule 19\nTopics\nCI/CD for AI Agents GitHub Actions, Docker\nCloud Infrastructure AWS S3, AWS ECR, AWS EC2, AWS\nBedrock\nModel Serving & Deployment BentoML\nEnd-to-End Agentic AI Projects Multiple Agentic AI Project\nAgentic And GenAI 2.0                                            Page  24')]

# %% [markdown]
# # CharacterTextSplitter

# %%
from langchain_text_splitters import CharacterTextSplitter
character_text_splitter = CharacterTextSplitter(
    separator="\n\n",
    chunk_size=100,
    chunk_overlap=20
)

final_documents = character_text_splitter.split_documents(data)
final_documents
# Out:
# [Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 0, 'page_label': '1'}, page_content='CI/CD &\nDEPLOYMENT\nMONITORING &\nCLOUD\nAGENTIC\nFRAMEWORKS'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 1, 'page_label': '2'}, page_content='This course is designed for AI developers, machine learning engineers, data scientists, and\nsoftware engineers looking to build expertise in agentic AI, multi-agent systems, and AI-powered\nautomation. Whether you are new to AI agents or have experience in NLP and GenAI, this course\nwill equip you with the knowledge and hands-on skills required to develop, deploy, and manage AI\nagents at scale. By the end of the course, you will have a strong foundation in agentic AI\nframeworks, multi-agent collaboration, real-world automation, and end-to-end AI deployment,\nalong with practical experience through real-world projects.\nLearning Objectives\n✅  Master AI Agent Frameworks: Build intelligent agents using LangChain, LangGraph,\nCrewAI, Agno, AutoGen, and LangFlow.\n✅  Develop Multi-Agent Systems: Design and deploy collaborative AI agents for real-\nworld tasks.\n✅  Implement RAG & Adaptive RAG: Build retrieval-augmented generation (RAG)\nsystems with vector databases.\n✅  Automate Workflows: Use n8n & LangFlow for AI-powered workflow automation.\n✅  Deploy AI Agents at Scale: Deploy agents using GitHub Actions, Docker, AWS, and\nBentoML.\n✅  Monitor & Optimize AI Agents: Track performance with LangSmith, Opik, and ClearML.\n✅  Build Real-World AI Applications: Create chatbots, financial agents, content\nautomation, and multi-agent systems.\nAgentic And GenAI 2.0                                              Page  2'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 2, 'page_label': '3'}, page_content='Course Information\nA foundational understanding of Python, NLP applications, and Generative AI applications is\nrecommended for this course. You should be comfortable working with Python and have\nexperience building NLP and GenAI applications. While the course will guide you through\nadvanced concepts, prior exposure to these topics will help you grasp the material more\neffectively and accelerate your learning.\nEstimated Time\n4 months 6hrs/week*\nRequired Skill Level\nIntermediate\nThe course is designed to be completed over a duration of approximately 4 months, covering a\nstructured progression from fundamental concepts to advanced agentic AI applications. The\ncurriculum includes theoretical foundations, hands-on coding exercises, real-world projects, and\ndeployment strategies, ensuring a comprehensive learning experience.\nPrerequisites\nAgentic And GenAI 2.0                                              Page  3'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 3, 'page_label': '4'}, page_content='Tools\nAgentic And GenAI 2.0                                              Page  4'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 4, 'page_label': '5'}, page_content='Course Instructors\nKrish NaikChief AI Engineer\nLinkedin\nSourangshu PalSenior Data Scientist\nLinkedin\nMayank AggrawalSenior ML Engineer\nLinkedin\nAgentic And GenAI 2.0                                              Page  5'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 5, 'page_label': '6'}, page_content="In this module, you'll explore the fundamentals of AI agents, understanding what they are and how\nthey function. You'll dive into the differences between Agentic AI, AI Agents, and Generative AI.\nThe module will also introduce you to multi-agent systems and various frameworks used to build\nthem. By the end, you will have a strong grasp of agent-based AI concepts, preparing you to work\nwith agentic AI frameworks in real-world applications.\nIntroduction to Agents\nModule 1\nTopics\nUnderstanding Agents What are Agents?\nAgentic AI Concepts Agentic AI vs AI Agents, Agentic AI vs\nGenerative AI\nMulti-Agent Systems & Frameworks What are Multi-Agents?, Agentic AI\nFrameworks\nAgentic And GenAI 2.0                                              Page  6"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 6, 'page_label': '7'}, page_content="In this module, you'll learn how to use Pydantic for efficient data validation and parsing in Python.\nYou'll start with installation and understanding models and fields. Then, you'll explore core\nvalidation techniques, including working with JSON, data types, and validators. Finally, you'll dive\ninto advanced concepts like validation decorators and monitoring Pydantic with Logfire. By the\nend, you'll be equipped to integrate Pydantic seamlessly into your projects for robust data\nvalidation.\nPydantic - Data Validation\nModule 2\nTopics\nGetting Started with Pydantic Installing, Models, Fields\nCore Validation & Data Handling JSON, Types, Validators, Dataclasses\nAdvanced Validation & Monitoring Validation Decorator, Monitor Pydantic\nwith Logfire\nAgentic And GenAI 2.0                                              Page  7"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 7, 'page_label': '8'}, page_content="In this module, you'll dive into Langchain, an essential framework for building AI-powered\napplications. You'll begin with an introduction to its core components and modules. Next, you'll\nexplore data ingestion and text-splitting techniques to preprocess documents effectively. Finally,\nyou'll learn about embeddings from OpenAI, Ollama, and Hugging Face, and how to store and\nretrieve vectorized data using FAISS and ChromaDB. By the end, you'll have a strong foundation\nfor working with Langchain in real-world AI applications.\nLangchain\nModule 3\nTopics\nIntroduction to Langchain Introduction to Basic Components and\nModules in Langchain\nData Ingestion & Processing Data Ingestion with Document Loaders,\nText Splitting Techniques (Recursive\nCharacter, Character, HTML Header,\nRecursive JSON)\nEmbeddings & Vector Stores Introduction to OpenAI Embedding,\nOllama Embeddings, Hugging Face\nEmbeddings, VectorStores-FAISS,\nVectorStore and Retriever - ChromaDB\nAgentic And GenAI 2.0                                              Page  8"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 8, 'page_label': '9'}, page_content="In this module, you'll explore Langchain Expression Language (LCEL) for building AI-powered\nworkflows. You'll start by working with open-source models using the Groq API. Next, you'll learn\nhow to construct LLMs, prompts, and structured output chains using LCEL. Finally, you'll deploy\nLCEL components as APIs using Langserve, making them accessible for real-world applications.\nBy the end, you'll have the skills to create and deploy LCEL-based AI solutions efficiently.\nLCEL (Langchain Expression Language)\nModule 4\nTopics\nGetting Started with LCEL Getting Started with Open Source\nModels Using Groq API\nBuilding LCEL Chains Building LLM, Prompt, and Stroutput\nChains with LCEL\nDeployment & API Integration Deploy Langserve Runnable and Chain\nas API\nAgentic And GenAI 2.0                                              Page  9"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 9, 'page_label': '10'}, page_content="In this module, you'll explore LangGraph, a framework for building AI-powered workflows using\ngraph-based structures. You'll begin with an introduction to its core concepts, including simple\ngraphs and LangGraph Studio. Next, you'll dive into key components like chains, routers, and\nagents with memory. Finally, you'll learn how to deploy LangGraph-based applications. By the end,\nyou'll have a solid understanding of LangGraph and its practical applications in AI development.\nLangGraph Introduction\nModule 5\nTopics\nGetting Started with LangGraph Introduction, Simple Graph, LangGraph\nStudio\nCore Components & Agents Chain, Router, Agent, Agent with\nMemory\nDeployment Essentials Intro to Deployment\nAgentic And GenAI 2.0                                              Page  10"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 10, 'page_label': '11'}, page_content="In this module, you'll dive into managing state and memory in LangGraph. You'll start by\nunderstanding state schemas and how multiple schemas can be utilized. Then, you'll explore\nmemory optimization techniques, including state reducers and message filtering, to efficiently\nhandle data in AI workflows. By the end, you'll have a solid grasp of state and memory\nmanagement, enabling you to build scalable and efficient LangGraph applications.\nState & Memory in LangGraph\nModule 6\nTopics\nUnderstanding State Management Introduction, State Schema, Multiple\nSchemas\nMemory Optimization State Reducers, Trim and Filter\nMessages\nAgentic And GenAI 2.0                                            Page  11"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 11, 'page_label': '12'}, page_content="In this module, you'll explore techniques to enhance user experience and integrate human\nfeedback in LangGraph workflows. You'll start with real-time streaming and breakpoints to control\nexecution flow. Then, you'll dive into editing states dynamically and incorporating human\nfeedback. Finally, you'll learn advanced debugging techniques like time travel for reviewing past\nstates. By the end, you'll be able to build interactive, user-friendly AI applications with LangGraph.\nUX and Human in Loop with LangGraph\nModule 7\nTopics\nEnhancing User Experience Streaming, Breakpoints\nHuman Feedback & State Control Editing State and Human Feedback,\nDynamic Breakpoints\nAdvanced Debugging Time Travel\nAgentic And GenAI 2.0                                            Page  12"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 12, 'page_label': '13'}, page_content="In this module, you'll learn how to deploy LangGraph applications efficiently. You'll start with\nfundamental deployment concepts and the process of creating a deployment. Then, you'll explore\nhow to connect and interact with your deployed LangGraph applications. By the end, you'll have\nthe skills to deploy and manage LangGraph solutions in real-world environments. \nLangGraph Deployments\nModule 8\nTopics\nDeployment Basics Deployment Concepts, Creating a\nDeployment\nIntegration & Access Connecting to a Deployment\nAgentic And GenAI 2.0                                            Page  13"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 13, 'page_label': '14'}, page_content="In this module, you'll explore Agno, a lightweight framework for building AI agents. You'll start by\nunderstanding its core components, including agents, teams, models, and tools. Next, you'll learn\nhow Agno handles data storage using chunking, vector databases, and embeddings. You'll dive\ninto workflows, agent observability, and UI features, enabling you to build and monitor intelligent\nagent systems effectively. You will also understand web search agents that retrieve and process\nonline information. Then, you'll delve into financial agents designed for analyzing market trends\nand financial data. Finally, you'll learn about RAG (Retrieval-Augmented Generation) agents,\nwhich enhance LLM capabilities with external knowledge retrieval.\nAgno - Light Framework\nModule 9\nTopics\nCore Concepts & Components Agents in Agno, Teams, Models, Tools,\nKnowledge\nData Handling & Storage Chunking, VectorDBs, Storage,\nEmbeddings\nWorkflows & Observability Workflows, Agent Observability, Agent\nPlayground, Agent UI\nAgno Projects Web Search Agents, Financial Agents,\nRAG Agents\nAgentic And GenAI 2.0                                            Page  14"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 14, 'page_label': '15'}, page_content="In this module, you'll dive into Agentic RAG (Retrieval-Augmented Generation) techniques, which\nenhance AI models with dynamic retrieval capabilities. You'll begin with adaptive RAG, learning\nhow to implement it locally and with services like Cohere. Then, you'll explore controlled RAG\napproaches like Agentic RAG and C-RAG, including their local implementations. Finally, you'll\ndiscover self-optimizing RAG methods that leverage vector databases for smarter knowledge\nretrieval. By the end, you'll be able to build advanced RAG-powered AI agents.\nAgentic RAG\nModule 10\nTopics\nAdaptive Retrieval-Augmented\nGeneration\nAdaptive RAG, Adaptive RAG with\nCohere, Adaptive RAG in Local\nControlled & Contextual RAG Agentic RAG, C-RAG, C-RAG in Local\nSelf-Optimizing RAG Self RAG, Self RAG in Local, Self RAG\nwith VectorDB\nAgentic And GenAI 2.0                                            Page  15"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 15, 'page_label': '16'}, page_content="In this module, you'll explore LangSmith, a powerful tool for managing AI workflows. You'll start\nwith an overview of its key features and role in AI development. Next, you'll learn how to set up\nLangSmith and navigate its user interface to utilize core functionalities. Finally, you'll dive into data\nintegration, preprocessing, and workflow pipelines, ensuring a seamless AI development process.\nBy the end, you'll have a strong foundation in using LangSmith to streamline AI projects.\nLangSmith\nModule 11\nTopics\nIntroduction & Setup What is LangSmith? Overview and Key\nFeatures, LangSmith in the AI\nDevelopment Workflow, Setting Up\nLangSmith: Installation and\nConfiguration\nCore Functionalities & UI Exploring the User Interface and Core\nFunctionalities, Understanding Workflow\nPipelines in LangSmith\nData Handling & Integration Data Integration in LangSmith,\nPreprocessing and Cleaning Data\nAgentic And GenAI 2.0                                            Page  16"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 16, 'page_label': '17'}, page_content="In this module, you'll learn how to design and implement multi-agent systems using LangGraph.\nYou'll start by building agent nodes and defining their roles. Next, you'll explore communication\nprotocols and coordination mechanisms that enable agents to work together effectively. Finally,\nyou'll learn how to scale multi-agent systems and apply your knowledge to real-world use cases.\nBy the end, you'll be able to create intelligent and scalable multi-agent architectures.\nDesigning Multi-Agent Systems with\nLangGraph\nModule 12\nTopics\nBuilding Agent Nodes & Roles Building Agent Nodes in LangGraph,\nDefining Tasks and Roles for Agents\nAgent Communication & Coordination Agent Communication Protocols and\nCoordination\nScalability & Real-World Applications Creating Scalable Multi-Agent Systems\nin LangGraph, Building a Real-World\nMulti-Agent System\nAgentic And GenAI 2.0                                            Page  17"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 17, 'page_label': '18'}, page_content="In this module, you'll explore CrewAI, a powerful multi-agent platform for building AI-driven\nworkflows. You'll begin with an introduction to its key features and capabilities. Next, you'll learn\nabout agent collaboration, communication, and workflow automation. You'll also discover how to\ncustomize CrewAI by managing data, implementing memory, defining roles, and using advanced\ntools. Finally, you'll integrate LangChain tools and monitor your CrewAI applications with Opik. By\nthe end, you'll be ready to design and deploy scalable multi-agent systems.\nCrewAI - Multi-Agent Platform\nModule 13\nTopics\nIntroduction & Core Features Definition and Overview, Key Features\nand Capabilities\nAgent Collaboration & Communication Crew Collaboration Framework, AI-\nAgent Communication, Workflow\nAutomation in CrewAI\nCustomization & Advanced\nCapabilities\nCustomizing CrewAI, Managing Data\nAcross Agents, Role-playing, Memory,\nTools, Focus, Guardrails\nIntegration & Monitoring Using LangChain Tools, Monitor your\nCrewAI applications with Opik\nAgentic And GenAI 2.0                                            Page  18"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 18, 'page_label': '19'}, page_content="In this module, you'll explore LangFlow, a low-code tool for building LLM applications with ease.\nYou'll begin with an introduction to its key features and use cases. Then, you'll learn how to set up\nyour LangFlow environment and navigate its UI. Finally, you'll dive into core concepts such as\nnodes, chains, and prompts before building your first LangFlow application. By the end, you'll be\nable to create and deploy LLM-powered workflows effortlessly\nLangFlow - Low Code Tool\nModule 14\nTopics\nIntroduction & Use Cases What is LangFlow? Overview and Use\nCases, Key Features of LangFlow for\nLLM Applications\nSetup & UI Navigation Setting Up Your LangFlow Environment,\nUnderstanding LangFlow UI and\nWorkflows\nCore Concepts & Quick Start Key Terminologies in LangFlow (Nodes,\nChains, Prompts), Quick Start: Creating\nYour First LangFlow Application\nAgentic And GenAI 2.0                                            Page  19"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 19, 'page_label': '20'}, page_content="In this module, you'll dive into the foundational elements of LangFlow. You'll begin by\nunderstanding core concepts like nodes, chains, and how LLMs integrate with LangFlow. Next,\nyou'll explore workflow customization, comparing pre-built and custom workflows while learning\nabout commonly used nodes. Finally, you'll cover prompt engineering and how to seamlessly\nintegrate LangChain with LangFlow. By the end, you'll have the knowledge to build and optimize\nintelligent workflows efficiently.\nBuilding Blocks of LangFlow\nModule 15\nTopics\nCore Concepts & Integration Nodes and Chains: Core Concepts,\nUnderstanding LLMs and Their\nIntegration with LangFlow\nWorkflows & Customization Pre-built vs. Custom Workflows,\nExploring Commonly Used LangFlow\nNodes\nPrompt Engineering & LangChain\nIntegration\nPrompt Engineering Basics in LangFlow,\nLangChain Integration: Using LangFlow\nwith LangChain\nAgentic And GenAI 2.0                                            Page  20"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 20, 'page_label': '21'}, page_content="In this module, you'll learn how to integrate LangFlow with various third-party tools and services.\nYou'll start by connecting LangFlow with different data sources like SQL, CSV, and NoSQL\ndatabases, along with external REST APIs. Next, you'll explore model integrations, including\nOpenAI, Hugging Face, and vector databases for embeddings. Finally, you'll delve into workflow\nautomation and chatbot development using LangFlow. By the end, you'll be able to build\nintelligent, automated applications with seamless integrations.\nIntegrating LangFlow with Third-Party\nTools\nModule 16\nTopics\nData & API Integration Connecting LangFlow with Data\nSources (SQL, CSV, NoSQL), API\nIntegration for External Services (REST\nAPIs)\nModel & Vector Database Integration Using LangFlow with Vector Databases\nfor Embeddings, LangFlow with OpenAI\nand Hugging Face Models\nWorkflow Automation & Chatbots Automating Workflows Using LangFlow,\nBuilding Chatbot Applications with\nLangFlow\nAgentic And GenAI 2.0                                            Page  21"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 21, 'page_label': '22'}, page_content="In this module, you'll get a comprehensive understanding of n8n, a powerful workflow automation\nplatform. You'll begin with the fundamentals, covering workflows, nodes, and core concepts. Then,\nyou'll explore APIs, webhooks, and error-handling techniques to ensure robust automation. You'll\nwill also learn to build AI-powered chatbots using Retrieval-Augmented Generation (RAG). Next,\nyou'll explore automation for content creation, such as generating blog posts with WordPress and\nalso implement AI-driven transcription and summarization workflows using Notion. Finally, you'll\ndive into AI-driven automation, including building AI agent chatbots and integrating tools like\nWhatsApp, Telegram, and calendars. By the end, you'll have the skills to create scalable and\nintelligent workflow automations with n8n.\nn8n\nModule 17\nTopics\nFundamentals & Core Concepts Introduction and Workflows, Interface,\nNodes, Core Workflow Concepts, Data in\nn8n\nAPI, Webhooks & Error Handling APIs and Webhooks, Useful Nodes, Error\nHandling, Debugging\nAI & Automation in n8n Build AI Agent Chatbot, Automations\nwith LLMs, Tools Integrations\n(WhatsApp, Telegram, Calendar)\nn8n Projects Building Automated RAG Chatbots,\nAutomate Blog Generation with\nWordPress, Automated Transcribe and\nSummarize with Notion\nAgentic And GenAI 2.0                                            Page  22"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 22, 'page_label': '23'}, page_content="In this module, you’ll get an introduction to AutoGen, an open-source framework for building and\nmanaging AI agents. You'll start with installation and core concepts, exploring how agents interact\nwithin goals, environments, and actions. You’ll then move on to designing agentic systems,\nincorporating feedback loops and decision-making frameworks. Finally, you'll explore multi-agent\ncollaboration and deployment strategies, ensuring scalability and performance monitoring. By the\nend of this module, you'll have a solid foundation in AutoGen and its applications in AI-driven\nautomation.\nAutogen\nModule 18\nTopics\nGetting Started with Autogen Overview of Autogen Framework,\nInstallation and Environment Setup\nCore Concepts of Autogen Agents, Goals, Environments, and\nActions, APIs, Libraries, and Tools\nBuilding Agentic Systems Designing and Developing Agentic\nSystems, Framework for Agentic\nDecision-Making\nAgent Interactions & Learning Communication Between Agents,\nImplementing Feedback Loops, Agent\nLearning and Adaptation\nMulti-Agent Collaboration Multi-Agent Collaboration, Deployment,\nMonitoring Agent Performance\nAgentic And GenAI 2.0                                            Page  23"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-04-03T18:36:52+00:00', 'title': 'AgenticAI-v2.0', 'moddate': '2025-04-03T18:36:40+00:00', 'keywords': 'DAGjmPTBGs4,BAEmsmap8Lg,0', 'author': 'monal singh', 'source': '/Users/amarmandal/Documents/coding/GenAI_Course/data/AgenticAI-v2.0.pdf', 'total_pages': 24, 'page': 23, 'page_label': '24'}, page_content="This module covers the full deployment pipeline for AI agents, providing hands-on experience with\nessential DevOps tools such as GitHub Actions, Docker, and cloud platforms like AWS S3, ECR,\nEC2, and Bedrock. You'll also explore model serving with BentoML. After mastering these\ndeployment concepts, you'll work on multiple end-to-end Agentic AI projects, applying these skills\nto real-world scenarios. By the end of this module, you'll be equipped to deploy, manage, and\nscale AI agents efficiently.\nDeploying AI Agents Stack & End-to-End\nAgentic AI Projects\nModule 19\nTopics\nCI/CD for AI Agents GitHub Actions, Docker\nCloud Infrastructure AWS S3, AWS ECR, AWS EC2, AWS\nBedrock\nModel Serving & Deployment BentoML\nEnd-to-End Agentic AI Projects Multiple Agentic AI Project\nAgentic And GenAI 2.0                                            Page  24")]

# %% [markdown]
# # HTML Splitter

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter


doc = """
<!DOCTYPE html>
<html lang="en">
<head>
<title>CSS Template</title>
<meta charset="utf-8">
<meta name="viewport" content="width=device-width, initial-scale=1">

</head>
<body>

<h2>CSS Layout Float</h2>
<p>In this example, we have created a header, two columns/boxes and a footer. On smaller screens, the columns will stack on top of each other.</p>
<p>Resize the browser window to see the responsive effect (you will learn more about this in our next chapter - HTML Responsive.)</p>

<header>
  <h2>Cities</h2>
</header>

<section>
  <nav>
    <ul>
      <li><a href="#">London</a></li>
      <li><a href="#">Paris</a></li>
      <li><a href="#">Tokyo</a></li>
    </ul>
  </nav>
  
  <article>
    <h1>London</h1>
    <p>London is the capital city of England. It is the most populous city in the  United Kingdom, with a metropolitan area of over 13 million inhabitants.</p>
    <p>Standing on the River Thames, London has been a major settlement for two millennia, its history going back to its founding by the Romans, who named it Londinium.</p>
  </article>
</section>

<footer>
  <p>Footer</p>
</footer>

</body>
</html>


"""

headers_to_split = [
    ("h1", "Header 1"), 
    ("h2", "Header 2"),
]
html_header_splitter = HTMLHeaderTextSplitter(headers_to_split)

final_documents = html_header_splitter.split_text(doc)
final_documents
# Out:
# [Document(metadata={'Header 2': 'CSS Layout Float'}, page_content='CSS Layout Float'),
#  Document(metadata={'Header 2': 'CSS Layout Float'}, page_content='In this example, we have created a header, two columns/boxes and a footer. On smaller screens, the columns will stack on top of each other.  \nResize the browser window to see the responsive effect (you will learn more about this in our next chapter - HTML Responsive.)'),
#  Document(metadata={'Header 2': 'Cities'}, page_content='Cities'),
#  Document(metadata={'Header 2': 'Cities'}, page_content='London  \nParis  \nTokyo'),
#  Document(metadata={'Header 1': 'London'}, page_content='London'),
#  Document(metadata={}, page_content='London is the capital city of England. It is the most populous city in the  United Kingdom, with a metropolitan area of over 13 million inhabitants.  \nStanding on the River Thames, London has been a major settlement for two millennia, its history going back to its founding by the Romans, who named it Londinium.  \nFooter')]

# %% [markdown]
# # Json Splitter

# %%
from langchain_text_splitters import RecursiveJsonSplitter
import json

import requests

# This is a large nested json object and will be loaded as a python dict
json_data = requests.get("https://api.smith.langchain.com/openapi.json").json()

splitter = RecursiveJsonSplitter(max_chunk_size=4)
json_chunks = splitter.split_json(json_data=json_data)
json_chunks
# Out:
# [{'openapi': '3.1.0', 'info': {'title': 'LangSmith'}},
#  {'info': {'version': '0.1.0'},
#   'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'summary': 'Get Tracing Project Prebuilt Dashboard'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'description': 'Get a prebuilt dashboard for a tracing project.'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'operationId': 'get_tracing_project_prebuilt_dashboard_api_v1_sessions__session_id__dashboard_post'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'parameters': [{'name': 'session_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Session Id'}},
#       {'name': 'accept',
#        'in': 'header',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'title': 'Accept'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/CustomChartsSectionRequest'}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/CustomChartsSection'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/dashboard': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'summary': 'Read Tracer Session'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'description': 'Get a specific session.'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'operationId': 'read_tracer_session_api_v1_sessions__session_id__get'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'parameters': [{'name': 'session_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Session Id'}},
#       {'name': 'include_stats',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'boolean',
#         'default': False,
#         'title': 'Include Stats'}},
#       {'name': 'accept',
#        'in': 'header',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'title': 'Accept'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/TracerSession'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'summary': 'Update Tracer Session'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'description': 'Create a new session.'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'operationId': 'update_tracer_session_api_v1_sessions__session_id__patch'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'parameters': [{'name': 'session_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'uuid',
#         'title': 'Session Id'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/TracerSessionUpdate'}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/TracerSessionWithoutVirtualFields'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'patch': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'summary': 'Delete Tracer Session'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'description': 'Delete a specific session.'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'operationId': 'delete_tracer_session_api_v1_sessions__session_id__delete'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'parameters': [{'name': 'session_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'uuid',
#         'title': 'Session Id'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}': {'delete': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'summary': 'Read Tracer Sessions'}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'description': 'Get all sessions.'}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'operationId': 'read_tracer_sessions_api_v1_sessions_get'}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'parameters': [{'name': 'reference_free',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'boolean'}, {'type': 'null'}],
#         'title': 'Reference Free'}},
#       {'name': 'reference_dataset',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'array',
#           'items': {'type': 'string', 'format': 'uuid'}},
#          {'type': 'null'}],
#         'title': 'Reference Dataset'}},
#       {'name': 'id',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'array',
#           'items': {'type': 'string', 'format': 'uuid'}},
#          {'type': 'null'}],
#         'title': 'Id'}},
#       {'name': 'name',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'title': 'Name'}},
#       {'name': 'name_contains',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'title': 'Name Contains'}},
#       {'name': 'dataset_version',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'title': 'Dataset Version'}},
#       {'name': 'sort_by',
#        'in': 'query',
#        'required': False,
#        'schema': {'$ref': '#/components/schemas/SessionSortableColumns',
#         'default': 'start_time'}},
#       {'name': 'sort_by_desc',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'boolean',
#         'default': True,
#         'title': 'Sort By Desc'}},
#       {'name': 'metadata',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'title': 'Metadata'}},
#       {'name': 'sort_by_feedback_key',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'title': 'Sort By Feedback Key'}},
#       {'name': 'offset',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'integer',
#         'minimum': 0,
#         'default': 0,
#         'title': 'Offset'}},
#       {'name': 'limit',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'integer',
#         'maximum': 100,
#         'minimum': 1,
#         'default': 100,
#         'title': 'Limit'}},
#       {'name': 'tag_value_id',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'array',
#           'items': {'type': 'string', 'format': 'uuid'}},
#          {'type': 'null'}],
#         'title': 'Tag Value Id'}},
#       {'name': 'facets',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'boolean', 'default': False, 'title': 'Facets'}},
#       {'name': 'filter',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'title': 'Filter'}},
#       {'name': 'include_stats',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'boolean',
#         'default': True,
#         'title': 'Include Stats'}},
#       {'name': 'use_approx_stats',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'boolean',
#         'default': False,
#         'title': 'Use Approx Stats'}},
#       {'name': 'accept',
#        'in': 'header',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'title': 'Accept'}}]}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'type': 'array'}}}}}}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'items': {'$ref': '#/components/schemas/TracerSession'}}}}}}}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'title': 'Response Read Tracer Sessions Api V1 Sessions Get'}}}}}}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'summary': 'Create Tracer Session'}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'description': 'Create a new session.'}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'operationId': 'create_tracer_session_api_v1_sessions_post'}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'parameters': [{'name': 'upsert',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'boolean',
#         'default': False,
#         'title': 'Upsert'}}]}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/TracerSessionCreate'}}}}}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/TracerSessionWithoutVirtualFields'}}}}}}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions': {'delete': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions': {'delete': {'summary': 'Delete Tracer Sessions'}}}},
#  {'paths': {'/api/v1/sessions': {'delete': {'description': 'Delete a specific session.'}}}},
#  {'paths': {'/api/v1/sessions': {'delete': {'operationId': 'delete_tracer_sessions_api_v1_sessions_delete'}}}},
#  {'paths': {'/api/v1/sessions': {'delete': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions': {'delete': {'parameters': [{'name': 'session_ids',
#        'in': 'query',
#        'required': True,
#        'schema': {'type': 'array',
#         'items': {'type': 'string', 'format': 'uuid'},
#         'title': 'Session Ids'}}]}}}},
#  {'paths': {'/api/v1/sessions': {'delete': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions': {'delete': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions': {'delete': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'summary': 'Read Tracer Sessions Runs Metadata'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'description': 'Given a session, a number K, and (optionally) a list of metadata keys, return the top K values for each key.'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'operationId': 'read_tracer_sessions_runs_metadata_api_v1_sessions__session_id__metadata_get'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'parameters': [{'name': 'session_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Session Id'}},
#       {'name': 'metadata_keys',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'array', 'items': {'type': 'string'}},
#          {'type': 'null'}],
#         'title': 'Metadata Keys'}},
#       {'name': 'start_time',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string', 'format': 'date-time'},
#          {'type': 'null'}],
#         'title': 'Start Time'}},
#       {'name': 'k',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'integer',
#         'minimum': 1,
#         'default': 10,
#         'title': 'K'}},
#       {'name': 'root_runs_only',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'boolean',
#         'default': False,
#         'title': 'Root Runs Only'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/RootModel_Dict_str__list_str___'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/metadata': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'summary': 'Read Filter Views'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'description': 'Get all filter views for a session.'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'operationId': 'read_filter_views_api_v1_sessions__session_id__views_get'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'parameters': [{'name': 'session_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Session Id'}},
#       {'name': 'type',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'$ref': '#/components/schemas/FilterViewType'},
#          {'type': 'null'}],
#         'title': 'Type'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'type': 'array'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'items': {'$ref': '#/components/schemas/FilterView'}}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'title': 'Response Read Filter Views Api V1 Sessions  Session Id  Views Get'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'summary': 'Create Filter View'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'description': 'Create a new filter view.'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'operationId': 'create_filter_view_api_v1_sessions__session_id__views_post'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'parameters': [{'name': 'session_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'uuid',
#         'title': 'Session Id'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/FilterViewCreate'}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/FilterView'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'get': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'get': {'summary': 'Read Filter View'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'get': {'description': 'Get a specific filter view.'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'get': {'operationId': 'read_filter_view_api_v1_sessions__session_id__views__view_id__get'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'get': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'get': {'parameters': [{'name': 'session_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Session Id'}},
#       {'name': 'view_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'uuid',
#         'title': 'View Id'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/FilterView'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'summary': 'Update Filter View'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'description': 'Update a filter view.'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'operationId': 'update_filter_view_api_v1_sessions__session_id__views__view_id__patch'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'parameters': [{'name': 'session_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Session Id'}},
#       {'name': 'view_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'uuid',
#         'title': 'View Id'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/FilterViewUpdate'}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/FilterView'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'patch': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'delete': {'tags': ['tracer-sessions']}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'delete': {'summary': 'Delete Filter View'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'delete': {'description': 'Delete a specific filter view.'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'delete': {'operationId': 'delete_filter_view_api_v1_sessions__session_id__views__view_id__delete'}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'delete': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'delete': {'parameters': [{'name': 'session_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Session Id'}},
#       {'name': 'view_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'uuid',
#         'title': 'View Id'}}]}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'delete': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'delete': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/sessions/{session_id}/views/{view_id}': {'delete': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'summary': 'List Organizations'}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'description': 'Get all orgs visible to this auth'}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'operationId': 'list_organizations_api_v1_orgs_get'}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'security': [{'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'parameters': [{'name': 'skip_create',
#        'in': 'query',
#        'required': False,
#        'schema': {'type': 'boolean',
#         'default': False,
#         'title': 'Skip Create'}}]}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'type': 'array'}}}}}}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'items': {'$ref': '#/components/schemas/OrganizationPGSchemaSlim'}}}}}}}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'title': 'Response List Organizations Api V1 Orgs Get'}}}}}}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs': {'post': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs': {'post': {'summary': 'Create Organization'}}}},
#  {'paths': {'/api/v1/orgs': {'post': {'operationId': 'create_organization_api_v1_orgs_post'}}}},
#  {'paths': {'/api/v1/orgs': {'post': {'security': [{'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/orgs': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/OrganizationCreate'}}}}}}}},
#  {'paths': {'/api/v1/orgs': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/OrganizationPGSchemaSlim'}}}}}}}}},
#  {'paths': {'/api/v1/orgs': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/setup': {'post': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/setup': {'post': {'summary': 'Create Customers And Get Stripe Setup Intent'}}}},
#  {'paths': {'/api/v1/orgs/current/setup': {'post': {'operationId': 'create_customers_and_get_stripe_setup_intent_api_v1_orgs_current_setup_post'}}}},
#  {'paths': {'/api/v1/orgs/current/setup': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/setup': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/StripeSetupIntentResponse'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/setup': {'post': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current': {'get': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current': {'get': {'summary': 'Get Organization Info'}}}},
#  {'paths': {'/api/v1/orgs/current': {'get': {'operationId': 'get_organization_info_api_v1_orgs_current_get'}}}},
#  {'paths': {'/api/v1/orgs/current': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Organization'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current': {'get': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'get': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'get': {'summary': 'Get Current Organization Info'}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'get': {'operationId': 'get_current_organization_info_api_v1_orgs_current_info_get'}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/OrganizationInfo'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'get': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'patch': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'patch': {'summary': 'Update Current Organization Info'}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'patch': {'operationId': 'update_current_organization_info_api_v1_orgs_current_info_patch'}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'patch': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/OrganizationUpdate'}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'patch': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'patch': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'patch': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/OrganizationInfo'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'patch': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'patch': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/info': {'patch': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/billing': {'get': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/billing': {'get': {'summary': 'Get Organization Billing Info'}}}},
#  {'paths': {'/api/v1/orgs/current/billing': {'get': {'operationId': 'get_organization_billing_info_api_v1_orgs_current_billing_get'}}}},
#  {'paths': {'/api/v1/orgs/current/billing': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/billing': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/OrganizationBillingInfo'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/billing': {'get': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'summary': 'Get Dashboard'}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'operationId': 'get_dashboard_api_v1_orgs_current_dashboard_get'}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'parameters': [{'name': 'type',
#        'in': 'query',
#        'required': True,
#        'schema': {'$ref': '#/components/schemas/OrganizationDashboardType'}},
#       {'name': 'color_scheme',
#        'in': 'query',
#        'required': True,
#        'schema': {'anyOf': [{'$ref': '#/components/schemas/OrganizationDashboardColorScheme'},
#          {'type': 'null'}],
#         'title': 'Color Scheme'}}]}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/OrganizationDashboardSchema'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs/current/dashboard': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'summary': 'On Payment Method Created'}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'operationId': 'on_payment_method_created_api_v1_orgs_current_payment_method_post'}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/StripePaymentInformation'}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/payment-method': {'post': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'get': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'get': {'summary': 'Get Company Info'}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'get': {'operationId': 'get_company_info_api_v1_orgs_current_business_info_get'}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/StripeBusinessInfo-Output'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'get': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'post': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'post': {'summary': 'Set Company Info'}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'post': {'operationId': 'set_company_info_api_v1_orgs_current_business_info_post'}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/StripeBusinessInfo-Input'}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/business-info': {'post': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'summary': 'Change Payment Plan'}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'operationId': 'change_payment_plan_api_v1_orgs_current_plan_post'}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/ChangePaymentPlanSchema'}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/plan': {'post': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'get': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'get': {'summary': 'List Organization Roles'}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'get': {'operationId': 'list_organization_roles_api_v1_orgs_current_roles_get'}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'items': {'$ref': '#/components/schemas/Role'}}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'type': 'array'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'title': 'Response List Organization Roles Api V1 Orgs Current Roles Get'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'get': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'post': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'post': {'summary': 'Create Organization Roles'}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'post': {'operationId': 'create_organization_roles_api_v1_orgs_current_roles_post'}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/CreateRoleRequest'}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Role'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles': {'post': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'delete': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'delete': {'summary': 'Delete Organization Roles'}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'delete': {'operationId': 'delete_organization_roles_api_v1_orgs_current_roles__role_id__delete'}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'delete': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'delete': {'parameters': [{'name': 'role_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'uuid',
#         'title': 'Role Id'}}]}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'delete': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'delete': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Role'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'delete': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'delete': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'summary': 'Update Organization Roles'}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'operationId': 'update_organization_roles_api_v1_orgs_current_roles__role_id__patch'}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'parameters': [{'name': 'role_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'uuid',
#         'title': 'Role Id'}}]}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/UpdateRoleRequest'}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/Role'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs/current/roles/{role_id}': {'patch': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/permissions': {'get': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/permissions': {'get': {'summary': 'List Permissions'}}}},
#  {'paths': {'/api/v1/orgs/permissions': {'get': {'operationId': 'list_permissions_api_v1_orgs_permissions_get'}}}},
#  {'paths': {'/api/v1/orgs/permissions': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/permissions': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'items': {'$ref': '#/components/schemas/PermissionResponse'}}}}}}}}}},
#  {'paths': {'/api/v1/orgs/permissions': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'type': 'array'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/permissions': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'title': 'Response List Permissions Api V1 Orgs Permissions Get'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/permissions': {'get': {'security': [{'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/pending': {'get': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/pending': {'get': {'summary': 'List Pending Organization Invites'}}}},
#  {'paths': {'/api/v1/orgs/pending': {'get': {'description': 'Get all pending orgs visible to this auth'}}}},
#  {'paths': {'/api/v1/orgs/pending': {'get': {'operationId': 'list_pending_organization_invites_api_v1_orgs_pending_get'}}}},
#  {'paths': {'/api/v1/orgs/pending': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/pending': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'items': {'$ref': '#/components/schemas/OrganizationPGSchemaSlim'}}}}}}}}}},
#  {'paths': {'/api/v1/orgs/pending': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'type': 'array'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/pending': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'title': 'Response List Pending Organization Invites Api V1 Orgs Pending Get'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/pending': {'get': {'security': [{'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'get': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'get': {'summary': 'Get Current Org Members'}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'get': {'operationId': 'get_current_org_members_api_v1_orgs_current_members_get'}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/OrganizationMembers'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'get': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'post': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'post': {'summary': 'Add Member To Current Org'}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'post': {'operationId': 'add_member_to_current_org_api_v1_orgs_current_members_post'}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/PendingIdentityCreate'}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/PendingIdentity'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/orgs/current/members': {'post': {'security': [{'API Key': []},
#       {'Organization ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/orgs/current/members/active': {'get': {'tags': ['orgs']}}}},
#  {'paths': {'/api/v1/orgs/current/members/active': {'get': {'summary': 'Get Current Active Org Members'}}}},
# ...
#         'title': 'Tag'}}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/version': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/version': {'get': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/DatasetVersion'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/version': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/version': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'tags': ['datasets']}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'summary': 'Update Dataset Version'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'description': 'Set a tag on a dataset version.'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'operationId': 'update_dataset_version_api_v1_datasets__dataset_id__tags_put'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'parameters': [{'name': 'dataset_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'uuid',
#         'title': 'Dataset Id'}}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/PutDatasetVersionsSchema'}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/DatasetVersion'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/tags': {'put': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai': {'get': {'tags': ['datasets']}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai': {'get': {'summary': 'Download Dataset Openai'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai': {'get': {'description': 'Download a dataset as OpenAI Evals Jsonl format.'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai': {'get': {'operationId': 'download_dataset_openai_api_v1_datasets__dataset_id__openai_get'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai': {'get': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai': {'get': {'parameters': [{'name': 'dataset_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Dataset Id'}},
#       {'name': 'as_of',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string', 'format': 'date-time'},
#          {'type': 'null'}],
#         'description': 'Only modifications made on or before this time are included. If None, the latest version of the dataset is used.',
#         'title': 'As Of'},
#        'description': 'Only modifications made on or before this time are included. If None, the latest version of the dataset is used.'}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai_ft': {'get': {'tags': ['datasets']}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai_ft': {'get': {'summary': 'Download Dataset Openai Ft'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai_ft': {'get': {'description': 'Download a dataset as OpenAI Jsonl format.'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai_ft': {'get': {'operationId': 'download_dataset_openai_ft_api_v1_datasets__dataset_id__openai_ft_get'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai_ft': {'get': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai_ft': {'get': {'parameters': [{'name': 'dataset_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Dataset Id'}},
#       {'name': 'as_of',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string', 'format': 'date-time'},
#          {'type': 'null'}],
#         'description': 'Only modifications made on or before this time are included. If None, the latest version of the dataset is used.',
#         'title': 'As Of'},
#        'description': 'Only modifications made on or before this time are included. If None, the latest version of the dataset is used.'}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai_ft': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai_ft': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/openai_ft': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/csv': {'get': {'tags': ['datasets']}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/csv': {'get': {'summary': 'Download Dataset Csv'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/csv': {'get': {'description': 'Download a dataset as CSV format.'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/csv': {'get': {'operationId': 'download_dataset_csv_api_v1_datasets__dataset_id__csv_get'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/csv': {'get': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/csv': {'get': {'parameters': [{'name': 'dataset_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Dataset Id'}},
#       {'name': 'as_of',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string', 'format': 'date-time'},
#          {'type': 'null'}],
#         'description': 'Only modifications made on or before this time are included. If None, the latest version of the dataset is used.',
#         'title': 'As Of'},
#        'description': 'Only modifications made on or before this time are included. If None, the latest version of the dataset is used.'}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/csv': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/csv': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/csv': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/jsonl': {'get': {'tags': ['datasets']}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/jsonl': {'get': {'summary': 'Download Dataset Jsonl'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/jsonl': {'get': {'description': 'Download a dataset as CSV format.'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/jsonl': {'get': {'operationId': 'download_dataset_jsonl_api_v1_datasets__dataset_id__jsonl_get'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/jsonl': {'get': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/jsonl': {'get': {'parameters': [{'name': 'dataset_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Dataset Id'}},
#       {'name': 'as_of',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string', 'format': 'date-time'},
#          {'type': 'null'}],
#         'description': 'Only modifications made on or before this time are included. If None, the latest version of the dataset is used.',
#         'title': 'As Of'},
#        'description': 'Only modifications made on or before this time are included. If None, the latest version of the dataset is used.'}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/jsonl': {'get': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/jsonl': {'get': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/jsonl': {'get': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'tags': ['datasets']}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'summary': 'Read Examples With Runs'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'description': 'Fetch examples for a dataset, and fetch the runs for each example if they are associated with the given session_ids.'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'operationId': 'read_examples_with_runs_api_v1_datasets__dataset_id__runs_post'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'parameters': [{'name': 'dataset_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string', 'format': 'uuid', 'title': 'Dataset Id'}},
#       {'name': 'format',
#        'in': 'query',
#        'required': False,
#        'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#         'description': "Response format, e.g., 'csv'",
#         'title': 'Format'},
#        'description': "Response format, e.g., 'csv'"}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/QueryExampleSchemaWithRuns'}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'anyOf': [{'type': 'array',
#             'items': {'$ref': '#/components/schemas/ExampleWithRuns'}},
#            {'type': 'array',
#             'items': {'$ref': '#/components/schemas/ExampleWithRunsCH'}},
#            {'type': 'null'}]}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'title': 'Response Read Examples With Runs Api V1 Datasets  Dataset Id  Runs Post'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'tags': ['datasets']}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'summary': 'Read Examples With Runs Grouped'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'description': 'Fetch examples for a dataset, and fetch the runs for each example if they are associated with the given session_ids.'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'operationId': 'read_examples_with_runs_grouped_api_v1_datasets__dataset_id__group_runs_post'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'parameters': [{'name': 'dataset_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'uuid',
#         'title': 'Dataset Id'}}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/QueryGroupedExamplesWithRuns'}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/GroupedExamplesWithRunsResponse'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/group/runs': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs/delta': {'post': {'tags': ['datasets']}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs/delta': {'post': {'summary': 'Read Delta'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs/delta': {'post': {'description': 'Fetch the number of regressions/improvements for each example in a dataset, between sessions[0] and sessions[1].'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs/delta': {'post': {'operationId': 'read_delta_api_v1_datasets__dataset_id__runs_delta_post'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs/delta': {'post': {'security': [{'API Key': []},
#       {'Tenant ID': []},
#       {'Bearer Auth': []}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs/delta': {'post': {'parameters': [{'name': 'dataset_id',
#        'in': 'path',
#        'required': True,
#        'schema': {'type': 'string',
#         'format': 'uuid',
#         'title': 'Dataset Id'}}]}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs/delta': {'post': {'requestBody': {'required': True}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs/delta': {'post': {'requestBody': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/QueryFeedbackDelta'}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs/delta': {'post': {'responses': {'200': {'description': 'Successful Response'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs/delta': {'post': {'responses': {'200': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/SessionFeedbackDelta'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs/delta': {'post': {'responses': {'422': {'description': 'Validation Error'}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/runs/delta': {'post': {'responses': {'422': {'content': {'application/json': {'schema': {'$ref': '#/components/schemas/HTTPValidationError'}}}}}}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/share': {'get': {'tags': ['datasets']}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/share': {'get': {'summary': 'Read Dataset Share State'}}}},
#  {'paths': {'/api/v1/datasets/{dataset_id}/share': {'get': {'description': 'Get the state of sharing a dataset'}}}},
#  ...]
