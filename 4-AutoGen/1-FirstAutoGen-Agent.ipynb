# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
model_client = OpenAIChatCompletionClient(
    model="gpt-4o",
)

# %%
agent_1 = AssistantAgent(
    name="my_assistant",
    model_client=model_client
)

# %%
result = await agent_1.run(task="What is the capital of France?")

# %%
result
# Out:
# TaskResult(messages=[TextMessage(id='253ee743-ea95-4c0f-b9f2-6130a3dc8fff', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 7, 7, 11, 25, 802100, tzinfo=datetime.timezone.utc), content='What is the capital of France?', type='TextMessage'), TextMessage(id='58112551-a9c4-42c8-b634-6f357ce93546', source='my_assistant', models_usage=RequestUsage(prompt_tokens=43, completion_tokens=9), metadata={}, created_at=datetime.datetime(2025, 7, 7, 7, 11, 27, 317984, tzinfo=datetime.timezone.utc), content='The capital of France is Paris. TERMINATE', type='TextMessage')], stop_reason=None)

# %%
result2 = await agent_1.run(task="What was the last question i asked?")

# %%
result2
# Out:
# TaskResult(messages=[TextMessage(id='bfc1f4c0-d4fa-4ec7-8534-fd78e24507f3', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 7, 7, 14, 59, 391678, tzinfo=datetime.timezone.utc), content='What was the last question i asked?', type='TextMessage'), TextMessage(id='2560a5f0-933b-4e5f-8d8d-2c3a1de61fea', source='my_assistant', models_usage=RequestUsage(prompt_tokens=69, completion_tokens=17), metadata={}, created_at=datetime.datetime(2025, 7, 7, 7, 15, 1, 848249, tzinfo=datetime.timezone.utc), content='The last question you asked was: "What is the capital of France?" TERMINATE', type='TextMessage')], stop_reason=None)
